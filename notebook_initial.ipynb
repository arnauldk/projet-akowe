# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#indicateurs_data : 886930
#indicateurs : 643638
#indicateurs_country_series 613
#indicateurs_country 241
#indicateurs_series 3665 rows × 22 columns
#donneeconnexion: 51 lignes
from   sqlalchemy import create_engine
import matplotlib.pyplot as plt
import pandas as pd
DataBase='postgresql://dataset_x9fe_user:j6gFJhCQ1oNiSvI8VKZuYTZzlYvOvypb@dpg-d4tbvft6ubrc73eikglg-a.oregon-postgres.render.com/dataset_x9fe'

engine = create_engine(DataBase)
countries =pd.read_sql( 'SELECT * FROM "indicateurs_country"',engine)
countries.head()
# Out:
#    id country_code   short_name   table_name                     long_name  \
# 0   1          ABW        Aruba        Aruba                         Aruba
# 1   2          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2   3          AGO       Angola       Angola   People's Republic of Angola
# 3   4          ALB      Albania      Albania           Republic of Albania
# 4   5          AND      Andorra      Andorra       Principality of Andorra
#
#   col_2_alpha_code   currency_unit  \
# 0               AW   Aruban florin
# 1               AF  Afghan afghani
# 2               AO  Angolan kwanza
# 3               AL    Albanian lek
# 4               AD            Euro
#
#                                        special_notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                               None
# ...

# %%
tb =pd.read_sql( 'SELECT * FROM "indicateurs_country"',engine)
tb.head()
# Out:
#    id country_code   short_name   table_name                     long_name  \
# 0   1          ABW        Aruba        Aruba                         Aruba
# 1   2          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2   3          AGO       Angola       Angola   People's Republic of Angola
# 3   4          ALB      Albania      Albania           Republic of Albania
# 4   5          AND      Andorra      Andorra       Principality of Andorra
#
#   col_2_alpha_code   currency_unit  \
# 0               AW   Aruban florin
# 1               AF  Afghan afghani
# 2               AO  Angolan kwanza
# 3               AL    Albanian lek
# 4               AD            Euro
#
#                                        special_notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                               None
# ...

# %%
df=pd.read_sql( 'SELECT * FROM "indicateurs_data"',engine)
df
# Out:
#             id  country_name country_code  \
# 0       736451       Somalia          SOM
# 1       736452       Somalia          SOM
# 2       736453       Somalia          SOM
# 3       736454       Somalia          SOM
# 4       736455       Somalia          SOM
# ...        ...           ...          ...
# 886925  736447       Somalia          SOM
# 886926  736448       Somalia          SOM
# 886927  736449       Somalia          SOM
# 886928  736450       Somalia          SOM
# 886929  737264  South Africa          ZAF
#
#                                            indicator_name  \
# 0       Wittgenstein Projection: Percentage of the pop...
# 1       Wittgenstein Projection: Percentage of the pop...
# 2       Wittgenstein Projection: Percentage of the pop...
# 3       Wittgenstein Projection: Percentage of the pop...
# 4       Wittgenstein Projection: Percentage of the pop...
# ...                                                   ...
# ...

# %%
ind=pd.read_sql( 'SELECT * FROM "indicateurs"',engine)
ind
# Out:
#             id countrycode      seriescode    year  \
# 0            1         ABW  SE.PRE.ENRL.FE  YR2001
# 1            2         ABW  SE.TER.TCHR.FE  YR2005
# 2            3         ABW  SE.PRE.TCHR.FE  YR2000
# 3            4         ABW  SE.SEC.ENRL.GC  YR2004
# 4            5         ABW     SE.PRE.TCHR  YR2006
# ...        ...         ...             ...     ...
# 643633  643634         ZWE     SH.DYN.MORT  YR2007
# 643634  643635         ZWE     SH.DYN.MORT  YR2014
# 643635  643636         ZWE     SH.DYN.MORT  YR2015
# 643636  643637         ZWE     SH.DYN.MORT  YR2017
# 643637  643638         ZWE     SP.POP.GROW  YR2017
#
#                                    description unnamed__4
# 0                          Country estimation.       None
# 1                          Country estimation.       None
# 2                          Country estimation.       None
# 3                          Country estimation.       None
# ...

# %%
indicators =[
    "NY.GDP.PCAP.CD",  # GDP per capita (current US$)
    "SE.TER.ENRL",  # Enrolment in tertiary education, all programmes, both sexes (number
    "IT.NET.USER.P2",    # Internet users (per 100 people)
    "SE.XPD.TOTL.GB.ZS",     # Government expenditure on education (% of government expenditure)
    "SP.POP.1564.TO.ZS",     # Population ages 15-64 (% of total)
    "SP.POP.0014.TO.ZS",  # Population ages 0-14 (% of total)
]

# Filtrer Afrique subsaherienne
ssa_codes= countries[countries["region"] == "Sub-Saharan Africa"]["country_code"]

# Filtrer Indicateurs + pays
df_ssa= df[
    (df["indicator_code"].isin(indicators)) &
    (df["country_code"].isin(ssa_codes))
]
df_ssa
# Out:
#             id  country_name country_code  \
# 1420    737870  South Africa          ZAF
# 1440    737890  South Africa          ZAF
# 1461    737911  South Africa          ZAF
# 1592    738041  South Africa          ZAF
# 2634    739085  South Africa          ZAF
# ...        ...           ...          ...
# 884707  734225       Somalia          SOM
# 884728  734246       Somalia          SOM
# 884855  734376       Somalia          SOM
# 885898  735420       Somalia          SOM
# 885964  735484       Somalia          SOM
#
#                                            indicator_name     indicator_code  \
# 1420    Enrolment in tertiary education, all programme...        SE.TER.ENRL
# 1440    Expenditure on education as % of total governm...  SE.XPD.TOTL.GB.ZS
# 1461                         GDP per capita (current US$)     NY.GDP.PCAP.CD
# 1592                      Internet users (per 100 people)     IT.NET.USER.P2
# ...

# %%
year_cols = [col for col in df_ssa.columns if col.startswith('col_') and col[4:].isdigit()]

df = df_ssa.melt(
    id_vars=['country_name', 'country_code', 'indicator_name', 'indicator_code'],
    value_vars=year_cols,
    var_name='Year',
    value_name='value'
)
df["Year"] = df["Year"].str.replace('col_', '').astype(int)
df["value"] = pd.to_numeric(df["value"], errors='coerce')
df.head()
# Out:
#    country_name country_code  \
# 0  South Africa          ZAF
# 1  South Africa          ZAF
# 2  South Africa          ZAF
# 3  South Africa          ZAF
# 4  South Africa          ZAF
#
#                                       indicator_name     indicator_code  Year  \
# 0  Enrolment in tertiary education, all programme...        SE.TER.ENRL  1970
# 1  Expenditure on education as % of total governm...  SE.XPD.TOTL.GB.ZS  1970
# 2                       GDP per capita (current US$)     NY.GDP.PCAP.CD  1970
# 3                    Internet users (per 100 people)     IT.NET.USER.P2  1970
# 4                 Population, ages 0-14 (% of total)  SP.POP.0014.TO.ZS  1970
#
#           value
# 0  82697.000000
# 1           NaN
# 2    818.488168
# 3           NaN
# 4     41.610168

# %%
df = df[df["Year"].between(2010, 2024)]
df.head()
# Out:
#        country_name country_code  \
# 11520  South Africa          ZAF
# 11521  South Africa          ZAF
# 11522  South Africa          ZAF
# 11523  South Africa          ZAF
# 11524  South Africa          ZAF
#
#                                           indicator_name     indicator_code  \
# 11520  Enrolment in tertiary education, all programme...        SE.TER.ENRL
# 11521  Expenditure on education as % of total governm...  SE.XPD.TOTL.GB.ZS
# 11522                       GDP per capita (current US$)     NY.GDP.PCAP.CD
# 11523                    Internet users (per 100 people)     IT.NET.USER.P2
# 11524                 Population, ages 0-14 (% of total)  SP.POP.0014.TO.ZS
#
#        Year        value
# 11520  2010          NaN
# 11521  2010    18.044371
# 11522  2010  7361.755850
# 11523  2010    24.000000
# 11524  2010    30.430068

# %%
df["value"] = pd.to_numeric(df["value"])
df = df.pivot_table(
    index=['country_name', "country_code", "Year" ],
    columns='indicator_name',
    values='value'
    ).reset_index()
df
# Out:
# indicator_name country_name country_code  Year  \
# 0                    Angola          AGO  2010
# 1                    Angola          AGO  2011
# 2                    Angola          AGO  2012
# 3                    Angola          AGO  2013
# 4                    Angola          AGO  2014
# ..                      ...          ...   ...
# 330                Zimbabwe          ZWE  2012
# 331                Zimbabwe          ZWE  2013
# 332                Zimbabwe          ZWE  2014
# 333                Zimbabwe          ZWE  2015
# 334                Zimbabwe          ZWE  2016
#
# indicator_name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                             NaN
# 1                                                        142798.0
# 2                                                             NaN
# 3                                                        218679.0
# ...

# %%
df.isna().sum()
# Out:
# indicator_name
# country_name                                                              0
# country_code                                                              0
# Year                                                                      0
# Enrolment in tertiary education, all programmes, both sexes (number)    168
# Expenditure on education as % of total government expenditure (%)       178
# GDP per capita (current US$)                                             10
# Internet users (per 100 people)                                           7
# Population, ages 0-14 (% of total)                                        7
# Population, ages 15-64 (% of total)                                       5
# dtype: int64

# %%
df.to_csv("df.csv", index=False)

# %%
df.head()
# Out:
# indicator_name country_name country_code  Year  \
# 0                    Angola          AGO  2010
# 1                    Angola          AGO  2011
# 2                    Angola          AGO  2012
# 3                    Angola          AGO  2013
# 4                    Angola          AGO  2014
#
# indicator_name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                             NaN
# 1                                                        142798.0
# 2                                                             NaN
# 3                                                        218679.0
# 4                                                             NaN
#
# indicator_name  Expenditure on education as % of total government expenditure (%)  \
# 0                                                         8.68477
# 1                                                             NaN
# ...

# %%
df=pd.read_csv("df.csv")
df.head()
# Out:
#   country_name country_code  Year  \
# 0       Angola          AGO  2010
# 1       Angola          AGO  2011
# 2       Angola          AGO  2012
# 3       Angola          AGO  2013
# 4       Angola          AGO  2014
#
#    Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                NaN
# 1                                           142798.0
# 2                                                NaN
# 3                                           218679.0
# 4                                                NaN
#
#    Expenditure on education as % of total government expenditure (%)  \
# 0                                            8.68477
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GDP per capita (current US$)  Internet users (per 100 people)  \
# ...

# %%
df = df.sort_values(["country_code", "Year"])

colonnes_num = df.select_dtypes(include="number").columns

# %%
df[colonnes_num] = (
    df.groupby("country_code")[colonnes_num]
      .apply(lambda x: x.interpolate(method="linear", limit_direction="both")
                    .ffill()
                    .bfill())
      .reset_index(level=0, drop=True)
)

# Remplir les derniers NaN
df[colonnes_num] = df[colonnes_num].apply(lambda x: x.fillna(x.median()))

# %%
df.isna().sum()
# Out:
# country_name                                                            0
# country_code                                                            0
# Year                                                                    0
# Enrolment in tertiary education, all programmes, both sexes (number)    0
# Expenditure on education as % of total government expenditure (%)       0
# GDP per capita (current US$)                                            0
# Internet users (per 100 people)                                         0
# Population, ages 0-14 (% of total)                                      0
# Population, ages 15-64 (% of total)                                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 335 entries, 0 to 334
# Data columns (total 9 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   country_name                                                          335 non-null    object
#  1   country_code                                                          335 non-null    object
#  2   Year                                                                  335 non-null    int64
#  3   Enrolment in tertiary education, all programmes, both sexes (number)  335 non-null    float64
#  4   Expenditure on education as % of total government expenditure (%)     335 non-null    float64
#  5   GDP per capita (current US$)                                          335 non-null    float64
# ...

# %%
df.describe()
# Out:
#               Year  \
# count   335.000000
# mean   2012.991045
# std       1.999231
# min    2010.000000
# 25%    2011.000000
# 50%    2013.000000
# 75%    2015.000000
# max    2016.000000
#
#        Enrolment in tertiary education, all programmes, both sexes (number)  \
# count                                       3.350000e+02
# mean                                        1.577513e+05
# std                                         2.763454e+05
# min                                         1.000000e+02
# 25%                                         2.550700e+04
# 50%                                         6.637850e+04
# 75%                                         1.345810e+05
# max                                         1.513371e+06
#
#        Expenditure on education as % of total government expenditure (%)  \
# count                                         335.000000
# mean                                           16.811629
# ...

# %%
#Histogramme – Accès à Internet
plt.figure(figsize=(5,3))
sns.histplot(
    df["Internet users (per 100 people)"],
    bins=20, color="red")
plt.title("Distribution de l'accès à Internet (%)")
plt.xlabel("Utilisateurs Internet (%)")
plt.ylabel("Nombre d'observations")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.histplot(
    df['Enrolment in tertiary education, all programmes, both sexes (number)'],
    bins=20)

plt.title("Distribution de l’inscription dans l’enseignement supérieur")
plt.xlabel("Taux d’inscription dans l’enseignement supérieur (%)")
plt.ylabel("Nombre d’observations")
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x=df["GDP per capita (current US$)"])
plt.title("Distribution du PIB par habitant")
plt.xlabel("PIB par habitant (USD)")
plt.show()

# %%
cols_corr = [
    "Enrolment in tertiary education, all programmes, both sexes (number)",
    "Expenditure on education as % of total government expenditure (%)",
    "GDP per capita (current US$)",
    "Internet users (per 100 people)",
    "Population, ages 0-14 (% of total)",
    "Population, ages 15-64 (% of total)"
]

sns.heatmap(
    df[cols_corr].corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Corrélation entre indicateurs sélectionnés")
plt.show()

# %%
df_median = df.groupby("country_name")["Internet users (per 100 people)"].median().sort_values()

# %%
plt.figure(figsize=(10, 8))  # Ajuste la hauteur si beaucoup de pays
sns.barplot(x=df_median.values, y=df_median.index, palette="viridis")

plt.title("Accès à Internet (%) par pays – Afrique subsaharienne (médiane)")
plt.xlabel("Utilisateurs Internet (%)")
plt.ylabel("Pays")
plt.show()
# Out:
# /tmp/ipython-input-3701586432.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df_median.values, y=df_median.index, palette="viridis")

# %% [markdown]
# Après interpolation temporelle par pays, certains indicateurs présentent encore un nombre limité de valeurs manquantes, principalement concentrées sur des pays ou des périodes sans aucune donnée initiale. Ces valeurs résiduelles ont été conservées, les agrégations statistiques par pays étant calculées en ignorant automatiquement les valeurs manquantes, conformément aux pratiques standards en analyse exploratoire.

# %%
#  Normalisation (0–100)

# %%
def min_max(series):
    return 100 * (series - series.min()) / (series.max() - series.min())

# %% [markdown]
# **Scale Score – Taille du marché (35 %)**

# %%
df["scale_raw"] = (
    np.log1p(df["Enrolment in tertiary education, all programmes, both sexes (number)"])
    * df["Internet users (per 100 people)"]
    * df["Population, ages 15-64 (% of total)"]
)

df["scale_score"] = min_max(df["scale_raw"])

# %% [markdown]
# Momentum Score – Dynamique (25 %)

# %%
momentum = (
    df
    .groupby("country_name")["Internet users (per 100 people)"]
    .apply(lambda x: x.iloc[-1] - x.iloc[0])
    .reset_index(name="internet_trend")
)

# %%
momentum["momentum_score"] = min_max(momentum["internet_trend"])

# %% [markdown]
# **Ability to Pay – Capacité de paiement (25 %)**

# %%
df["ability_raw"] = (
    df["GDP per capita (current US$)"] * df["Expenditure on education as % of total government expenditure (%)"] / 100
)

df["ability_score"] = min_max(df["ability_raw"])

# %% [markdown]
# **Digital Readiness – Faisabilité (15 %)**

# %%
df["digital_raw"] = df["Internet users (per 100 people)"]
df["digital_score"] = min_max(df["digital_raw"])

# %% [markdown]
# **Agrégation par pays**

# %%
scores = (
    df
    .groupby("country_name")[["scale_score", "ability_score", "digital_score"]]
    .mean()
    .reset_index()
    .merge(momentum, on="country_name")
)

# %% [markdown]
# **Calcul final du MAS**

# %%
scores["MAS"] = (
    0.35 * scores["scale_score"]
    + 0.25 * scores["momentum_score"]
    + 0.25 * scores["ability_score"]
    + 0.15 * scores["digital_score"]
)

# %% [markdown]
# **Classement final des pays**

# %%
scores = scores.sort_values("MAS", ascending=False)
scores.head(10)
# Out:
#          country_name  scale_score  ability_score  digital_score  \
# 39       South Africa    79.013717      35.742374      75.682402
# 28          Mauritius    62.143774      43.312788      72.259146
# 16              Gabon    41.308002      28.168739      54.498759
# 2            Botswana    35.169852      31.957821      43.509861
# 36         Seychelles    40.811695      39.952628      86.736085
# 13  Equatorial Guinea    20.953141      78.770418      27.517589
# 5          Cabo Verde    46.536048      13.312539      68.081138
# 18              Ghana    28.446456       9.843694      33.194721
# 30            Namibia    22.860197      37.768428      30.122518
# 42          Swaziland    23.442877      21.779975      38.561121
#
#     internet_trend  momentum_score        MAS
# 39       30.000000       85.586459  69.339370
# 28       24.896178       71.025858  61.173854
# 16       35.052274      100.000000  54.674799
# 2        33.362997       95.180694  50.620556
# ...

# %% [markdown]
# **Visualisations**

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=scores.head(10), x="MAS", y="country_name")
plt.title("Top 10 des pays d’Afrique subsaharienne – Market Attractiveness Score")
plt.xlabel("MAS")
plt.ylabel("")
plt.show()

# %% [markdown]
# Heatmap des sous-scores (Top 10)

# %%
heatmap_data = scores.set_index("country_name")[
    ["scale_score", "momentum_score", "ability_score", "digital_score"]
].head(10)

plt.figure(figsize=(4,2))
sns.heatmap(heatmap_data, cmap="coolwarm")
plt.title("Sous-scores du MAS – Top 10 pays")
plt.show()

# %% [markdown]
# **Segmentation**

# %%
def segment_market(mas):
    if mas >= 50:
        return "Priorité 1 – Go-to-Market"
    elif mas >= 35:
        return "Priorité 2 – Build & Partnerships"
    else:
        return "Priorité 3 – Niche / Long terme"

# %%
scores["segment"] = scores["MAS"].apply(segment_market)
scores.head(10)
# Out:
#          country_name  scale_score  ability_score  digital_score  \
# 39       South Africa    79.013717      35.742374      75.682402
# 28          Mauritius    62.143774      43.312788      72.259146
# 16              Gabon    41.308002      28.168739      54.498759
# 2            Botswana    35.169852      31.957821      43.509861
# 36         Seychelles    40.811695      39.952628      86.736085
# 13  Equatorial Guinea    20.953141      78.770418      27.517589
# 5          Cabo Verde    46.536048      13.312539      68.081138
# 18              Ghana    28.446456       9.843694      33.194721
# 30            Namibia    22.860197      37.768428      30.122518
# 42          Swaziland    23.442877      21.779975      38.561121
#
#     internet_trend  momentum_score        MAS  \
# 39       30.000000       85.586459  69.339370
# 28       24.896178       71.025858  61.173854
# 16       35.052274      100.000000  54.674799
# 2        33.362997       95.180694  50.620556
# ...

# %%
scores["segment"].value_counts()
# Out:
# segment
# Priorité 3 – Niche / Long terme      39
# Priorité 2 – Build & Partnerships     5
# Priorité 1 – Go-to-Market             4
# Name: count, dtype: int64

# %%
countries_focus = ["South Africa", "Ghana", "Mauritius"]

plt.figure(figsize=(5,3))
for c in countries_focus:
    subset = df[df["country_name"] == c]
    plt.plot(
        subset["Year"],
        subset["Internet users (per 100 people)"],
        label=c
    )

plt.title("Évolution de l’accès à Internet dans certains pays clés")
plt.xlabel("Année")
plt.ylabel("Utilisateurs Internet (pour 100 habitants)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.lineplot(
    data=df,
    x="Year",
    y="Enrolment in tertiary education, all programmes, both sexes (number)",
    estimator="mean"
)
plt.title("Évolution moyenne du taux de scolarisation secondaire en Afrique subsaharienne")
plt.xlabel("Année")
plt.ylabel("Taux de scolarisation (%)")
plt.show()

# %%
df.to_csv("df.csv", index=False)

# %%
df.isna().sum()
# Out:
# country_name                                                            0
# country_code                                                            0
# Year                                                                    0
# Enrolment in tertiary education, all programmes, both sexes (number)    0
# Expenditure on education as % of total government expenditure (%)       0
# GDP per capita (current US$)                                            0
# Internet users (per 100 people)                                         0
# Population, ages 0-14 (% of total)                                      0
# Population, ages 15-64 (% of total)                                     0
# scale_raw                                                               0
# scale_score                                                             0
# ability_raw                                                             0
# ability_score                                                           0
# ...
